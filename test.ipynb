# %%
import matplotlib.pyplot as plt
from cycler import cycler

# Load your custom dark style
plt.style.use(
    "https://raw.githubusercontent.com/dipunew/style/main/dark_plot_style.txt"
)

# %%
import numpy as np

x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

fig, ax = plt.subplots()
ax.plot(x, y1, label="sin(x)")
ax.plot(x, y2, label="cos(x)")
ax.set_title("Dark Plot Style Test")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

xs = np.linspace(0, 10, 100)
fig, ax = plt.subplots()

ax.plot(xs, np.sin(xs))
ax.plot(xs, 0.5 * np.sin(2 * xs + 2))
ax.plot(xs, 0.2 * np.sin(2.5 * xs + 0.4))
ax.plot(xs, 0.1 * xs + 0.1 * np.sin(1.5 * xs + 0.1))
ax.plot(xs, -0.1 * xs + 0.1 * np.sin(1.5 * xs + 0.1))

# This respects style and ensures tight layout
ax.margins(x=0.02, y=0.05)

plt.show()
